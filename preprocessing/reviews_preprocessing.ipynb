# %%
import pandas as pd

df = pd.read_csv("./data/corpora/reviews_raw/reviews.csv")

df
# Out:
#       deceptive             hotel  polarity       source  \
# 0      truthful            conrad  positive  TripAdvisor
# 1      truthful             hyatt  positive  TripAdvisor
# 2      truthful             hyatt  positive  TripAdvisor
# 3      truthful              omni  positive  TripAdvisor
# 4      truthful             hyatt  positive  TripAdvisor
# ...         ...               ...       ...          ...
# 1595  deceptive  intercontinental  negative        MTurk
# 1596  deceptive            amalfi  negative        MTurk
# 1597  deceptive  intercontinental  negative        MTurk
# 1598  deceptive            palmer  negative        MTurk
# 1599  deceptive            amalfi  negative        MTurk
#
#                                                    text
# 0     We stayed for a one night getaway with family ...
# 1     Triple A rate with upgrade to view room was le...
# 2     This comes a little late as I'm finally catchi...
# ...

# %%
trutful_df = df.loc[df["deceptive"] == "truthful"]
trutful_df = trutful_df["text"]
#iterate over a series
for index, value in trutful_df.items():
    path = "./data/corpora/trutful_reviews/truthful"+str(index)
    with open(path, "x") as reviewFile:
        reviewFile.write(value)
        reviewFile.close()

# %%
deceptive_df = df.loc[df["deceptive"] == "deceptive"]
deceptive_df = deceptive_df["text"]
#iterate over a series
for index, value in deceptive_df.items():
    path = "./data/corpora/deceptive_reviews/deceptive"+str(index)
    with open(path, "x") as reviewFile:
        reviewFile.write(value)
        reviewFile.close()

# %% [markdown]
# deceptive_df

# %%
import pandas as pd

ham = pd.read_csv("./data/results/ham.csv")
spam = pd.read_csv("./data/results/spam.csv")
nlkt = pd.read_csv("./data/results/nltkCorpus.csv")

df = ham.append(spam, ignore_index = True)
df = df.append(nlkt, ignore_index = True)
df
# Out:
# C:\Users\lbiondo\AppData\Local\Temp\ipykernel_47312\803187336.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = ham.append(spam, ignore_index = True)
# C:\Users\lbiondo\AppData\Local\Temp\ipykernel_47312\803187336.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(nlkt, ignore_index = True)
#     parsable  confidence_tokenizer  confidence_pos  confidence_ner  \
# 0  97.916649             97.026816       80.668134       98.458660
# 1  98.449264             97.256091       75.252477       96.940830
# 2  98.814070             99.032663       92.731658       97.240201
#
#    confidence_chunker  spelling_mistakes  avg_sentence_len  lexical_diversity  \
# 0           87.940408          94.797876         43.206345          94.817754
# ...
